# %%
import pandas as pd

# %%
netflix_titles_df = pd.read_csv('MoviesOnStreamingPlatforms_updated.csv')

# %%
Ages = netflix_titles_df["Age"]
Ages = Ages.str.rstrip('+')
Ages
# Out:
# 0         13
# 1         18
# 2         13
# 3          7
# 4         18
#         ...
# 16739    NaN
# 16740      7
# 16741    NaN
# 16742    NaN
# 16743    NaN
# Name: Age, Length: 16744, dtype: object

# %%
netflix_titles_df["Age"] = Ages

# %%
netflix_titles_df['Rotten Tomatoes'] = netflix_titles_df['Rotten Tomatoes']/100

# %%
clean_df = netflix_titles_df.drop(columns={"Unnamed: 0","ID", "Hulu","Prime Video","Disney+","Type", "IMDb"})
clean_df
# Out:
#                                 Title  Year  Age  Rotten Tomatoes  Netflix  \
# 0                           Inception  2010   13             87.0        1
# 1                          The Matrix  1999   18             87.0        1
# 2              Avengers: Infinity War  2018   13             84.0        1
# 3                  Back to the Future  1985    7             96.0        1
# 4      The Good, the Bad and the Ugly  1966   18             97.0        1
# ...                               ...   ...  ...              ...      ...
# 16739       The Ghosts of Buxley Hall  1980  NaN              NaN        0
# 16740                  The Poof Point  2001    7              NaN        0
# 16741           Sharks of Lost Island  2013  NaN              NaN        0
# 16742              Man Among Cheetahs  2017  NaN              NaN        0
# 16743                In Beaver Valley  1950  NaN              NaN        0
#
# ...

# %%
clean_df = clean_df.dropna()
clean_df
# Out:
#                                 Title  Year Age  Rotten Tomatoes  Netflix  \
# 0                           Inception  2010  13             87.0        1
# 1                          The Matrix  1999  18             87.0        1
# 2              Avengers: Infinity War  2018  13             84.0        1
# 3                  Back to the Future  1985   7             96.0        1
# 4      The Good, the Bad and the Ugly  1966  18             97.0        1
# ...                               ...   ...  ..              ...      ...
# 16657    A Kid in King Arthur's Court  1995   7              5.0        0
# 16671          George of the Jungle 2  2003   7             17.0        0
# 16677                   That Darn Cat  1997   7             13.0        0
# 16687                          Kazaam  1996   7              6.0        0
# 16705                Meet the Deedles  1998   7              7.0        0
#
#                             Directors  \
# 0                   Christopher Nolan
# ...

# %%
filt = clean_df["Netflix"] == 1
filt

clean_df = clean_df.loc[filt,:]

# %%
clean_df.to_csv("Netflix_Rotten_Tomatoes_Scores.csv", index=False)

# %%
rotten_tomatoes_df = pd.read_csv('Netflix_Rotten_Tomatoes_Scores.csv')
rotten_tomatoes_df
# Out:
#                               Title  Year Age  Rotten Tomatoes  Netflix  \
# 0                         Inception  2010  13             87.0        1
# 1                        The Matrix  1999  18             87.0        1
# 2            Avengers: Infinity War  2018  13             84.0        1
# 3                Back to the Future  1985   7             96.0        1
# 4    The Good, the Bad and the Ugly  1966  18             97.0        1
# ..                              ...   ...  ..              ...      ...
# 995                  I Am Vengeance  2018  18             38.0        1
# 996              Beneath The Leaves  2019  18             20.0        1
# 997                  Viking Destiny  2018  18             13.0        1
# 998                      Black Rose  2014  18             22.0        1
# 999                          Mantra  2017  13             40.0        1
#
#                           Directors                            Genres  \
# ...
