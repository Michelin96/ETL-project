# %%
import pandasql
import pandas as pd
import sqlite3

# %%
# Connect to sqlite and printout table names
con = sqlite3.connect('imdb.sqlite')
cursor = con.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('movies',), ('principals',), ('ratings',), ('names',)]

# %%
# View movies table
movies = pd.read_sql_query("SELECT * FROM movies", con)
movies.head(1)
# Out:
#       tconst titleType primaryTitle originalTitle  isAdult startYear endYear  \
# 0  tt0000009     movie   Miss Jerry    Miss Jerry      0.0      1894      \N
#
#   runtimeMinutes   genres
# 0             45  Romance

# %%
# Determine number of records for movies table
movies.tconst.count()
# Out:
# 328449

# %%
# View principals table
principals = pd.read_sql_query("SELECT * FROM principals", con)
principals.head(1)
# Out:
#       tconst  ordering     nconst category job  \
# 0  tt0000009       1.0  nm0063086  actress  \N
#
#                                  characters
# 0  ["Miss Geraldine Holbrook (Miss Jerry)"]

# %%
# Determine number of records in principals table
principals.tconst.count()
# Out:
# 2659855

# %%
# View ratings table
ratings = pd.read_sql_query("SELECT * FROM ratings", con)
ratings.head(1)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000009            5.4      81.0

# %%
# Determine number of records in ratings table
ratings.tconst.count()
# Out:
# 210982

# %%
# View names table
names = pd.read_sql_query("SELECT * FROM names", con)
names.head(1)
# Out:
#       nconst   primaryName birthYear deathYear  \
# 0  nm0000001  Fred Astaire      1899      1987
#
#                 primaryProfession                           knownForTitles
# 0  soundtrack,actor,miscellaneous  tt0053137,tt0043044,tt0050419,tt0072308

# %%
# Determine number of records in names table
names.nconst.count()
# Out:
# 989105

# %%
# Join movies and ratings table using tconst value
join = movies.set_index('tconst').join(ratings.set_index('tconst'))

# %%
join
# Out:
#           titleType                                       primaryTitle  \
# tconst
# tt0000009     movie                                         Miss Jerry
# tt0000147     movie                      The Corbett-Fitzsimmons Fight
# tt0000502     movie                                           Bohemios
# tt0000574     movie                        The Story of the Kelly Gang
# tt0000679     movie                     The Fairylogue and Radio-Plays
# ...             ...                                                ...
# tt9916186     movie  Illenau - die Geschichte einer ehemaligen Heil...
# tt9916190     movie                                          Safeguard
# tt9916538     movie                                Kuambil Lagi Hatiku
# tt9916680     movie  De la ilusión al desconcierto: cine colombiano...
# tt9916730     movie                                             6 Gunn
#
#                                                originalTitle  isAdult  \
# tconst
# tt0000009                                         Miss Jerry      0.0
# tt0000147                      The Corbett-Fitzsimmons Fight      0.0
# tt0000502                                           Bohemios      0.0
# tt0000574                        The Story of the Kelly Gang      0.0
# tt0000679                     The Fairylogue and Radio-Plays      0.0
# ...                                                      ...      ...
# tt9916186  Illenau - die Geschichte einer ehemaligen Heil...      0.0
# tt9916190                                          Safeguard      0.0
# tt9916538                                Kuambil Lagi Hatiku      0.0
# tt9916680  De la ilusión al desconcierto: cine colombiano...      0.0
# tt9916730                                             6 Gunn      0.0
#
#           startYear endYear runtimeMinutes                  genres  \
# tconst
# tt0000009      1894      \N             45                 Romance
# tt0000147      1897      \N             20  Documentary,News,Sport
# tt0000502      1905      \N            100                      \N
# tt0000574      1906      \N             70   Biography,Crime,Drama
# tt0000679      1908      \N            120       Adventure,Fantasy
# ...             ...     ...            ...                     ...
# tt9916186      2017      \N             84             Documentary
# tt9916190      2020      \N             90         Action,Thriller
# tt9916538      2019      \N            123                   Drama
# tt9916680      2007      \N            100             Documentary
# tt9916730      2017      \N            116                      \N
#
#            averageRating  numVotes
# tconst
# tt0000009            5.4      81.0
# tt0000147            5.2     310.0
# tt0000502            NaN       NaN
# tt0000574            6.1     538.0
# tt0000679            4.8      32.0
# ...                  ...       ...
# tt9916186            NaN       NaN
# tt9916190            NaN       NaN
# tt9916538            NaN       NaN
# tt9916680            NaN       NaN
# tt9916730            NaN       NaN
#
# [328449 rows x 10 columns]

# %%
# Determine number of records in join dataframe
join.genres.count()
# Out:
# 328449

# %%
# Remove records that do not have a rating
join1 = join[join['averageRating'].notna()]

# %%
join1
# Out:
#           titleType                    primaryTitle  \
# tconst
# tt0000009     movie                      Miss Jerry
# tt0000147     movie   The Corbett-Fitzsimmons Fight
# tt0000574     movie     The Story of the Kelly Gang
# tt0000679     movie  The Fairylogue and Radio-Plays
# tt0001184     movie         Don Juan de Serrallonga
# ...             ...                             ...
# tt9914286     movie               Sokagin Çocuklari
# tt9914642     movie                       Albatross
# tt9914644     movie    9/11: Escape from the Towers
# tt9914942     movie      La vida sense la Sara Amat
# tt9916160     movie                      Drømmeland
#
#                             originalTitle  isAdult startYear endYear  \
# tconst
# tt0000009                      Miss Jerry      0.0      1894      \N
# tt0000147   The Corbett-Fitzsimmons Fight      0.0      1897      \N
# tt0000574     The Story of the Kelly Gang      0.0      1906      \N
# tt0000679  The Fairylogue and Radio-Plays      0.0      1908      \N
# tt0001184         Don Juan de Serrallonga      0.0      1910      \N
# ...                                   ...      ...       ...     ...
# tt9914286               Sokagin Çocuklari      0.0      2019      \N
# tt9914642                       Albatross      0.0      2017      \N
# tt9914644    9/11: Escape from the Towers      0.0      2018      \N
# tt9914942      La vida sense la Sara Amat      0.0      2019      \N
# tt9916160                      Drømmeland      0.0      2019      \N
#
#           runtimeMinutes                  genres  averageRating  numVotes
# tconst
# tt0000009             45                 Romance            5.4      81.0
# tt0000147             20  Documentary,News,Sport            5.2     310.0
# tt0000574             70   Biography,Crime,Drama            6.1     538.0
# tt0000679            120       Adventure,Fantasy            4.8      32.0
# tt0001184             58         Adventure,Drama            3.1      11.0
# ...                  ...                     ...            ...       ...
# tt9914286             98            Drama,Family            7.1     190.0
# tt9914642             97             Documentary            8.4      18.0
# tt9914644            120             Documentary            8.4      28.0
# tt9914942             74                   Drama            6.9      39.0
# tt9916160             72             Documentary            6.5      31.0
#
# [210982 rows x 10 columns]

# %%
# Remove extraneous columns
imdb = join1.drop(['isAdult', 'endYear'], 1)

# %%
imdb
# Out:
#           titleType                    primaryTitle  \
# tconst
# tt0000009     movie                      Miss Jerry
# tt0000147     movie   The Corbett-Fitzsimmons Fight
# tt0000574     movie     The Story of the Kelly Gang
# tt0000679     movie  The Fairylogue and Radio-Plays
# tt0001184     movie         Don Juan de Serrallonga
# ...             ...                             ...
# tt9914286     movie               Sokagin Çocuklari
# tt9914642     movie                       Albatross
# tt9914644     movie    9/11: Escape from the Towers
# tt9914942     movie      La vida sense la Sara Amat
# tt9916160     movie                      Drømmeland
#
#                             originalTitle startYear runtimeMinutes  \
# tconst
# tt0000009                      Miss Jerry      1894             45
# tt0000147   The Corbett-Fitzsimmons Fight      1897             20
# tt0000574     The Story of the Kelly Gang      1906             70
# tt0000679  The Fairylogue and Radio-Plays      1908            120
# tt0001184         Don Juan de Serrallonga      1910             58
# ...                                   ...       ...            ...
# tt9914286               Sokagin Çocuklari      2019             98
# tt9914642                       Albatross      2017             97
# tt9914644    9/11: Escape from the Towers      2018            120
# tt9914942      La vida sense la Sara Amat      2019             74
# tt9916160                      Drømmeland      2019             72
#
#                            genres  averageRating  numVotes
# tconst
# tt0000009                 Romance            5.4      81.0
# tt0000147  Documentary,News,Sport            5.2     310.0
# tt0000574   Biography,Crime,Drama            6.1     538.0
# tt0000679       Adventure,Fantasy            4.8      32.0
# tt0001184         Adventure,Drama            3.1      11.0
# ...                           ...            ...       ...
# tt9914286            Drama,Family            7.1     190.0
# tt9914642             Documentary            8.4      18.0
# tt9914644             Documentary            8.4      28.0
# tt9914942                   Drama            6.9      39.0
# tt9916160             Documentary            6.5      31.0
#
# [210982 rows x 8 columns]

# %%
imdb.to_csv('imdb.csv', encoding='utf-8', index=False)
